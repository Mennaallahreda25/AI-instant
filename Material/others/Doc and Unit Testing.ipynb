# %% [markdown]
# # DocTest Rules
#
# Module showing how doctests can be included with source code
# Each '>>' line is run as if in a python shell, and counts as a test.
# The next line, if not '>>>' is the expected output of the previous line.
# If anything doesn't match exactly (including trailing spaces), the test fails.
#
# هدفه هو اختبار البرمجيات و تدريبة على الاجابات الصحيحة ثم اختباره و هذا يساعد فى تقليل الاخطاء البرمجية بالبرامج

# %%
import doctest
def sum(a,b):
    '''
    Calculates the sum of a and b
    ››> sum(1,1)
    2
    >›> sum(1, -1)
    0
    >›> sum(-1, -1)
    -2
    >›> sum (0, -10)
    -10
    ››>'''
    return a+b

if __name__=="__main__":
    doctest.testmod()

# %% [markdown]
# # Doc Testing - Pass Results

# %%
import doctest
def sum(a,b) :
    '''
    Calculates the sum of a and b
    ››> sum(1,1)
    2
    ››> sum(1, -1)
    0
    ››> sum (-1, -1)
    -2
    ›>> sum(0, -10)
    -10
    ››>'''
    return a+b

if __name__== "main":
    doctest.testmod()

# %% [markdown]
# ![WhatsApp%20Image%202023-07-05%20at%2003.39.42.jpeg](attachment:WhatsApp%20Image%202023-07-05%20at%2003.39.42.jpeg)

# %% [markdown]
# # Doctest fails

# %%
import doctest
def sum(a,b):
    '''
    Calculates the sum of a and b
    >›› sum(1,1)
    2
    ››> sum(1, -1)
    0
    ››> sum(-1, -1)
    -2
    ››> sum(0, -10)
    -10
    ›>>'''

    return a - b

if __name__=="main":
    doctest.testmod()

# %% [markdown]
# ![WhatsApp%20Image%202023-07-05%20at%2003.40.52.jpeg](attachment:WhatsApp%20Image%202023-07-05%20at%2003.40.52.jpeg)

# %% [markdown]
# # Doc Testing - Function Sample

# %%
import doctest
def Largest(first, second):
    '''
    Calculates the largest of first and second
    ››> Largest(4,5)
    5
    ››› Largest (5,4)
    5
    >›> Largest (5,5)
    5
    '''
    if (first > second):
        return first 
    return second
if __name__=="main":
    doctest.testmod()

# %%
import doctest
def Largest(first, second) :
    '''Calculates the largest of first and second
    ››> Largest (4,5)
    5
    >>> Largest (5,4)
    5
    ››> Largest (5,5)
    5
    '''
    if (first < second):
        return first
    return second
if __name__=="main":
    doctest. testmod()

# %% [markdown]
# ![WhatsApp%20Image%202023-07-05%20at%2003.40.52%20%281%29.jpeg](attachment:WhatsApp%20Image%202023-07-05%20at%2003.40.52%20%281%29.jpeg)

# %%
#############################################################################################################################

# %% [markdown]
# ![WhatsApp%20Image%202023-06-23%20at%2001.32.12.jpeg](attachment:WhatsApp%20Image%202023-06-23%20at%2001.32.12.jpeg)

# %% [markdown]
# # Unit Testing - Function Sample

# %%
import unittest
def Largest(first, second) :
    if (first > second):
        return first 
    return second

class SimpleTest(unittest. TestCase):
    def testLargest(self):
        self.assertEqual(Largest(4,5),5)
        self.assertEqual(Largest (5,4),5)
        self.assertEqual(Largest (5,5),5)

if __name__=="main":
    unittest.main(verbosity=2)

# %%
import unittest

def Largest(first, second):
    if (first < second):
        return first 
    return second
class SimpleTest(unittest.TestCase):
    def testLargest(self):
        self.assertEqual(Largest (4,5),5)
        self.assertEqual(Largest (5,4),5)
        self.assertEqual(Largest (5,5),5)

        import unittest
def Largest(first, second) :
    if (first > second):
        return first 
    return second

class SimpleTest(unittest. TestCase):
    def testLargest(self):
        self.assertEqual(Largest(4,5),5)
        self.assertEqual(Largest (5,4),5)
        self.assertEqual(Largest (5,5),5)

if __name__=="main":
    unittest.main(verbosity=2)

# %% [markdown]
# ![WhatsApp%20Image%202023-07-05%20at%2003.40.53.jpeg](attachment:WhatsApp%20Image%202023-07-05%20at%2003.40.53.jpeg)

# %%
##############################################################################################################################

# %%
import unittest
def add(x, y);
    return × + y
class SimpleTest(unittest.TestCase):
    def testadd1 (self):
        self.assertEquals(add(4,5),9)
if __name__=="main":
    unittest.main()

# %%
import unittest
def add (x,y) :
    return X + y
class SimpleTest(unittest.TestCase):
    def testadd1(self):
        self.assertEquals(add (10,5),9)
if __name__=="main":
    unittest.main()

# %% [markdown]
# ![WhatsApp%20Image%202023-07-05%20at%2003.40.53%20%281%29.jpeg](attachment:WhatsApp%20Image%202023-07-05%20at%2003.40.53%20%281%29.jpeg)

# %% [markdown]
# # Unit Testing - Pass Results

# %%
import unittest
class TestStringMethods (unittest.TestCase):
    def test_upper(self):
        self.assertEqual('foo'.upper(), 'FOO')
    def test_isupper(self):
        self.assertTrue('FOO'.isupper ())
        self.assertFalse('Foo'.isupper ())
    def test_split(self):
        s = 'hello world'
        self.assertEqual(s.split(), ['hello', 'world'])
        # check that s.split fails when the separator is not a string
        with self.assertRaises (TypeError):
            s.split(2)

if __name__=='main':
    unittest.main()

# %% [markdown]
# output:
#
# ran 3 tests in 0.004s
# ok

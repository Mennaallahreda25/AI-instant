# %% [markdown]
# # Statistics

# %% [markdown]
# ![WhatsApp%20Image%202023-06-20%20at%2000.05.20.jpeg](attachment:WhatsApp%20Image%202023-06-20%20at%2000.05.20.jpeg)

# %% [markdown]
# # Statistics Examples

# %%
import statistics as st

# %%
st.mean ([l, 2, 3, 4, 4])
st.harmonic mean ([2.5, 3, 10])
st.median ([1, 3, 5, 7])
st.median_low ([l, 3, 5])
st.median_high ([l, 3, 5, 7])
st.median_grouped ( [52, 52, 53, 54])
st.mode ([1, 1, 2, 3, 3, 3, 3, 4])
st.pstdev ([1.5, 2.5, 2.5, 2.75, 3.25, 4.75])
st.Pvariance ([0.0, 0.25, 0.25, 1.25, 1.5])
st.stdev ([1.5, 2.5, 2.5, 2.75, 3.25, 4.75])
st.st.variance ([0.0, 0.25, 0.25, 1.25, 1.5])

# %% [markdown]
# # Random Lib

# %%
import random

# %%
print ( random. random () )
print ( random. randrange (6) )
print ( random. choice ( ['apple','banana ' ])
print ( random. sample (range (100), 5) )
print ( random. choice ('abcdefghij') )

# %%
items = [1, 2, 3, 4, 5, 6, 7]
random. shuffle (items)
print ( items )

# %%
print ( random. randint (1, 10) )
print ( random. randrange (0, 101, 2) )
print ( random. uniform (1, 10))

# %% [markdown]
# # Mathimatics

# %% [markdown]
# ![WhatsApp%20Image%202023-06-20%20at%2000.06.40.jpeg](attachment:WhatsApp%20Image%202023-06-20%20at%2000.06.40.jpeg)

# %% [markdown]
# # Math Examples

# %%
import math

# %%
print ('n: %.40f' % math.pi)
print ('e: %.40f' % math.e)

# %%
print ('arcsine (%.1f)= %5.2f' % (n,math.asin (n) ))
print ('arccosine (%.1f) = %5.2f' % (n, math.acos (n) ) )
print ('arctangent (%.1f) = %5.2f' % (n, math.atan (n) ))

# %%
n = 100.7
print (math. floor (n) )
print (math.ceil (n))

# %%
print ( math. fsum ( [2, 6, 8])) 
print ( sum ( [2, 6, 8]))
print (math. pow (2, 3) )
print (math.sqrt (9))

# %% [markdown]
# # SymPy Sample Functions

# %%
# Use this code to run all the Code in this slide and the next 2 slides

import sympy as sym
x = sym. Symbol ('x')
y, i ,n, a, b = sym. symbols ('y i n a b')

# %%
f = x**2 + 1 
print ( f. subs (x, 2))

# %%
f = x**2 + 1 
print ( f. subs (x, 2))
print ( sym.expand ( (x + y) ** 3 )
print ( sym.simplify ((x + x * y) / x) )
print sym.limit (sym.sin(x) / x, x, 0))
print ( sym.diff (x**4, x) )
print ( sym. integrate (6 * × ** 5, x) )
print ( sym. solveset (x - 1, x) )

# %%
solution = sym.solve ( (x + 5 * y- 2, -3*x+6* Y - 15), (X, Y) )
print (solution [x], solution [y])

# %%
print (sym. integrate (exp (x) *sin (x)+ exp (x) *cos (x) , x) )

# %%
print (sym. summation (1/2**i, (i, 0, sym.oo))) 
print (sym. summation (1/1og (n) **n, (n, 2, sym. oo) ))

# %%
print ( sym.limit (l / x, x, sym.oo))

# %%
print (sym.summation (2*i - 1, (i, 1, n) ))

# %%
a = (x + 1) **2 + 5*x
b = x*2 + 2*x + 4
print (sym.simplify (a - b))

# %%
func = x*2 + 2*x*y - 2 *z
print (func.subs ([(x, 1), (y, 6), (z, -1)]) )

# %%
str func = "2*x +1"
func = sympify(str_func)
print (func)

# %%
func = sin (x)
print ( func.evalf (subs=(x: 1.2)))

# %%
print (factor (×*3 - x*2 + x - 1) )
print (factor (x*2*z+4*x*y*z+4*y*2*z））

# %%
print ( sym.integrate (exp (-x**2 - y**2), (x, -sym.oo, sym.oo), (Y, -sym.oo, sym.oo) ))

# %%
print (sym.solveset (×-2, x) )

# %%
print (sym.solveset (Eq (x-2, 1), x) )

# %%
m1 = sym. Matrix ([[1, 2, 3], [3, 2, 1]])
m2 = sym. Matrix ([0, 1, 1])
m3= sym. Matrix ([2, 3, 0]) 
print (m1)
print ( m1*m2 )
print (m2+m3)

# %%
m4= sym.zeros (2, 3) 
m5= sym.eye (3) 
print (m4) 
print (m5)
print (sym. ones (3, 2)) 
print (sym. diag (1, 2, 3) )

# %% [markdown]
# # Plotting using Sympy

# %%
from sympy import symbols 
from sympy plotting import plot
x = symbols ('x')

# %%
plot (×**2, (x, -5, 5))

# %%
plot((×* *2,(×,-6,6)），（×,（×,-5,5)））

# %% [markdown]
# # 3D Plotting using Sympy

# %%
from sympy import symbols 
from sympy.plotting import plot3d
x, y = symbols ('x y')
f=x**2*y**2
plot3d (f, (×,-5,5),(y,-5,5) )

# %%
from sympy import symbols 
from sympy.plotting import plot3d
x, y = symbols ('x y')
f=cos (x) +sin (y)
plot3d (f, (x, -10, 10), (y, -10, 10))

# %%
from sympy import symbols 
from sympy plotting import plot3d
X, y = symbols ('× y')
plot3d (x*y, (x, -5, 5), (y, -5, 5))
plot3d(x*y, -x*y, (x, -5, 5), (y, -5, 5))
plot3d( （×**2+y**2,(×,-5,5),(y,-5,5)），(x*y, (x, -3,3),(y,-3,3)))

# %% [markdown]
# # SymPy modules

# %% [markdown]
# • Assumptions: The assumption engine
#
# • Concrete: Symbolic products and summations
#
# • Core basic class structure: Basic, Add, Mul, Pow, and so on
#
# • Functions: Elementary and special functions
#
# • Galgebra: Geometric algebra
#
# • Geometry: Geometric entities
#
# • Integrals: Symbolic integrator
#
# • Interactive: Interactive sessions (for example, |Python)
#
# • Logic: Boolean algebra and theorem proving
#
# • Matrices: Linear algebra and matrices
#
# • mpmath: Fast arbitrary precision numerical math
#
# • ntheory: Number theoretical functions
#
# • Parsing: Mathematica and maxima parsers
#
# • Physics: Physical units and quantum stuff
#
# • Plotting: 2D and 3D plots using Pyglet
#
# • Polys: Polynomial algebra and factorization
#
# • Printing: Pretty-printing and code generation
#
# • Series: Symbolic limits and truncated series
#
# • Simplify: Rewriting expressions in other forms
#
# • Solvers: Algebraic, recurrence, and differential
#
# • Statistics: Standard probability distributions
#
# • Utilities: Test frameworks and compatibility-related content
